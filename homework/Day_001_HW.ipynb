# %%
import numpy as np
import matplotlib.pyplot as plt
w=3
b=0.5
x_lin=np.linspace(0,100,101)
y=(x_lin+np.random.randn(101)*5)*w+b
y_hat=x_lin*w+b
plt.plot(x_lin,y,'b.',label='data points')
plt.plot(x_lin,y_hat,"r-",label='data expect')
plt.title('we have data+expect')
plt.legend(loc=2)
plt.show()

# %%
def mean_square_error(y,yp):
    mse=MSE=sum((y-yp)*(y-yp))/len(y)
    return mse
MSE=mean_square_error(y,y_hat)
print('the mean square error is ',(MSE))
# Out:
# the mean square error is  191.387158575494

# %%
HW2:
    I chose the Data of covid-19 world vaccination progress.
    1為何重要：了解目前各國疫苗施打的進度及比例。
    2從何而來：Our World in Data GitHub repository for covid-19 
    3資料型態：結構化資料（表格），包括疫苗廠牌，施打人數，整體比例，每日施打次數，資料來源等等
    4這組資料想解決的問題如何評估：這組織料想解決問題分三部分：
        1了解各國所使用的疫苗廠牌：可使用圓餅圖了解目前各國施打各廠牌疫苗所佔各國比例
        2各國疫苗施打進度：the percentage of (complete) vaccinated people of each country
        3各國疫苗施打速度以及是否有高施打速度但低施打比例之國家：比較各國每日施打次數及各國疫苗施打比例

# %%
HW3:
    1核心問題：促銷活動及廣告投放是否可以提昇短期（促銷活動或廣告投放期間）及長期（促銷活動或廣告投放後ㄅ1-3個月之變化）之業績
    （單一客戶及全體客戶消費金額及頻率）
    2資料從何而來：線上預訂或電話預訂之紀錄，及各司機開出之發票及金額
    3資料型態：包含結構化（線上預訂紀錄）及非結構化（其他）之資料
    4如何評估：分析單一客戶及全體客戶於促銷活動或廣告投放前，促銷活動或廣告投放期間及促銷活動或廣告投放後一個月兩個月三個月之消費頻率及金額變化
        相較於平時，促銷活動或廣告投放是否增加消費金額及頻率。
        促銷活動或廣告投放過後第一個月第二個月及第三個月之消費金額與頻率相較於促銷活動或廣告投放之前以及促銷活動或廣告投放期間之變化。
